# %%
#-- 16 frames --
#-- Only 150 video for each class

# %%
#-- Install Libraries -------------------------------------------------------------------------------------------
# !pip install pytorchvideo

from IPython import display
display.clear_output()
#-----------------------------------------------------------------------------------------------------------------

# %%
#-- Imports ------------------------------------------------------------------------------------------------------
import torch

from typing import Dict
import json
import urllib
from torchvision.transforms import Compose, Lambda
from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)
from pytorchvideo.data.encoded_video import EncodedVideo
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample,
    UniformCropVideo
) 

import torchvision
import torchvision.transforms as transforms

from sklearn.model_selection import train_test_split



import cv2

import numpy as np
import random

import os
import shutil
import copy
#-----------------------------------------------------------------------------------------------------------------
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
#-- Initialize ---------------------------------------------------------------------------------------------------
ds_input_path = '/kaggle/input/real-life-violence-situations-dataset/Real Life Violence Dataset/'
ds_preprocessed_path = '/kaggle/working/ds/'
CLASS_NAMES = ['Violence', 'NonViolence']
#-----------------------------------------------------------------------------------------------------------------

# %%
#-- Create Folders  ----------------------------------------------------------------------------------------------
os.makedirs(ds_preprocessed_path, exist_ok=True)
#-----------------------------------------------------------------------------------------------------------------

# %%
#-- Check Number of Frames and Resolution of Videos ------------------------------------------------------------
i = 0
for root, dirs, files in os.walk(ds_input_path):
    
    for filename in files:
        file_path = os.path.join(root, filename)   
        
        if file_path.endswith(('.mp4')):          
            cap = cv2.VideoCapture(file_path)        

            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

            num_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            print(f"Video: {filename} | number of frames: {num_frames} - Resolution: {width} x {height}")

            # Release the video capture object
            cap.release()
            
            i += 1
            
            if i>=10:
                break
#-------------------------------------------------------------------------------------------------------------
# Out:
# Video: NV_759.mp4 | number of frames: 125 - Resolution: 224 x 224
# Video: NV_564.mp4 | number of frames: 125 - Resolution: 224 x 224
# Video: NV_126.mp4 | number of frames: 150 - Resolution: 224 x 224
# Video: NV_601.mp4 | number of frames: 105 - Resolution: 224 x 224
# Video: NV_397.mp4 | number of frames: 55 - Resolution: 224 x 224
# Video: NV_782.mp4 | number of frames: 115 - Resolution: 224 x 224
# Video: NV_143.mp4 | number of frames: 150 - Resolution: 224 x 224
# Video: NV_650.mp4 | number of frames: 145 - Resolution: 224 x 224
# Video: NV_639.mp4 | number of frames: 145 - Resolution: 224 x 224
# Video: NV_948.mp4 | number of frames: 145 - Resolution: 224 x 224
# Video: V_465.mp4 | number of frames: 141 - Resolution: 1280 x 720

# %%
side_size = 256
mean = [0.45, 0.45, 0.45]
std = [0.225, 0.225, 0.225]
crop_size = 256
num_frames = 32
sampling_rate = 2
frames_per_second = 30
slowfast_alpha = 4
num_clips = 10
num_crops = 3

class PackPathway(torch.nn.Module):
    """
    Transform for converting video frames as a list of tensors. 
    """
    def __init__(self):
        super().__init__()
        
    def forward(self, frames: torch.Tensor):
        fast_pathway = frames
        # Perform temporal sampling from the fast pathway.
        slow_pathway = torch.index_select(
            frames,
            1,
            torch.linspace(
                0, frames.shape[1] - 1, frames.shape[1] // slowfast_alpha
            ).long(),
        )
        frame_list = [slow_pathway, fast_pathway]
        return frame_list

transform =  ApplyTransformToKey(
    key="video",
    transform=Compose(
        [
            UniformTemporalSubsample(num_frames),
            Lambda(lambda x: x/255.0),
            NormalizeVideo(mean, std),
            ShortSideScale(
                size=side_size
            ),
            CenterCropVideo(crop_size),
            PackPathway()
        ]
    ),
)

# The duration of the input clip is also specific to the model.
clip_duration = (num_frames * sampling_rate)/frames_per_second

# %%
#-- Function to Preprocess videos -------------------------------------------------------------------------------
def preprocess_video(video_path, output_path):   
    start_sec = 0
    end_sec = start_sec + clip_duration
    video = EncodedVideo.from_path(video_path)
    video_data = video.get_clip(start_sec=start_sec, end_sec=end_sec)
    video_data = transform(video_data)
    inputs = video_data["video"]  
    torch.save(inputs, output_path)  
#-------------------------------------------------------------------------------------------------------------

# %%
#-- Preprocees and Split Data ------------------------------------------------------------------------------------
def preprocess_all_videos(input_folder, out_dir):
    
    #-- Create output directories if they don't exist --    
    os.makedirs(out_dir, exist_ok=True)
    
    i=0

    for class_name in CLASS_NAMES:
        class_folder = os.path.join(input_folder, class_name)
       
        #-- Get all video files in the class folder --
        videos = [f for f in os.listdir(class_folder) if f.endswith(('.mp4', '.avi', '.mov'))]
        
        random.seed(42)
        random.shuffle(videos)
        
        videos = videos[0:150]      
        
        out_folder = os.path.join(ds_preprocessed_path, class_name)
        os.makedirs(out_folder, exist_ok=True)
            
        
        for video in videos:
            i = i+1
            video_path = os.path.join(class_folder, video)            
            output_path = os.path.join(out_folder, video.replace('.mp4', '.pth'))
            preprocess_video(video_path, output_path)
            print(f'i= {i} :Processed and saved {video} to {out_folder}')
#-------------------------------------------------------------------------------------------------------------

# %%
#-- Run the preprocessing and splitting --
preprocess_all_videos(input_folder= ds_input_path,
                      out_dir= ds_preprocessed_path)
#-------------------------------------------------------------------------------------------------------------
# Out:
# i= 1 :Processed and saved V_39.mp4 to /kaggle/working/ds/Violence
# i= 2 :Processed and saved V_126.mp4 to /kaggle/working/ds/Violence
# i= 3 :Processed and saved V_758.mp4 to /kaggle/working/ds/Violence
# i= 4 :Processed and saved V_558.mp4 to /kaggle/working/ds/Violence
# i= 5 :Processed and saved V_700.mp4 to /kaggle/working/ds/Violence
# i= 6 :Processed and saved V_253.mp4 to /kaggle/working/ds/Violence
# i= 7 :Processed and saved V_372.mp4 to /kaggle/working/ds/Violence
# i= 8 :Processed and saved V_278.mp4 to /kaggle/working/ds/Violence
# i= 9 :Processed and saved V_498.mp4 to /kaggle/working/ds/Violence
# i= 10 :Processed and saved V_698.mp4 to /kaggle/working/ds/Violence
# i= 11 :Processed and saved V_705.mp4 to /kaggle/working/ds/Violence
# i= 12 :Processed and saved V_33.mp4 to /kaggle/working/ds/Violence
# i= 13 :Processed and saved V_528.mp4 to /kaggle/working/ds/Violence
# i= 14 :Processed and saved V_94.mp4 to /kaggle/working/ds/Violence
# i= 15 :Processed and saved V_287.mp4 to /kaggle/working/ds/Violence
# i= 16 :Processed and saved V_789.mp4 to /kaggle/working/ds/Violence
# i= 17 :Processed and saved V_57.mp4 to /kaggle/working/ds/Violence
# i= 18 :Processed and saved V_471.mp4 to /kaggle/working/ds/Violence
# i= 19 :Processed and saved V_545.mp4 to /kaggle/working/ds/Violence
# i= 20 :Processed and saved V_696.mp4 to /kaggle/working/ds/Violence
# i= 21 :Processed and saved V_342.mp4 to /kaggle/working/ds/Violence
# i= 22 :Processed and saved V_484.mp4 to /kaggle/working/ds/Violence
# i= 23 :Processed and saved V_795.mp4 to /kaggle/working/ds/Violence
# i= 24 :Processed and saved V_880.mp4 to /kaggle/working/ds/Violence
# i= 25 :Processed and saved V_818.mp4 to /kaggle/working/ds/Violence
# i= 26 :Processed and saved V_238.mp4 to /kaggle/working/ds/Violence
# i= 27 :Processed and saved V_216.mp4 to /kaggle/working/ds/Violence
# i= 28 :Processed and saved V_123.mp4 to /kaggle/working/ds/Violence
# i= 29 :Processed and saved V_833.mp4 to /kaggle/working/ds/Violence
# i= 30 :Processed and saved V_447.mp4 to /kaggle/working/ds/Violence
# i= 31 :Processed and saved V_606.mp4 to /kaggle/working/ds/Violence
# i= 32 :Processed and saved V_250.mp4 to /kaggle/working/ds/Violence
# i= 33 :Processed and saved V_596.mp4 to /kaggle/working/ds/Violence
# i= 34 :Processed and saved V_801.mp4 to /kaggle/working/ds/Violence
# i= 35 :Processed and saved V_271.mp4 to /kaggle/working/ds/Violence
# i= 36 :Processed and saved V_335.mp4 to /kaggle/working/ds/Violence
# i= 37 :Processed and saved V_376.mp4 to /kaggle/working/ds/Violence
# i= 38 :Processed and saved V_223.mp4 to /kaggle/working/ds/Violence
# i= 39 :Processed and saved V_180.mp4 to /kaggle/working/ds/Violence
# i= 40 :Processed and saved V_51.mp4 to /kaggle/working/ds/Violence
# i= 41 :Processed and saved V_127.mp4 to /kaggle/working/ds/Violence
# i= 42 :Processed and saved V_50.mp4 to /kaggle/working/ds/Violence
# i= 43 :Processed and saved V_576.mp4 to /kaggle/working/ds/Violence
# i= 44 :Processed and saved V_807.mp4 to /kaggle/working/ds/Violence
# i= 45 :Processed and saved V_593.mp4 to /kaggle/working/ds/Violence
# i= 46 :Processed and saved V_540.mp4 to /kaggle/working/ds/Violence
# i= 47 :Processed and saved V_689.mp4 to /kaggle/working/ds/Violence
# i= 48 :Processed and saved V_417.mp4 to /kaggle/working/ds/Violence
# i= 49 :Processed and saved V_247.mp4 to /kaggle/working/ds/Violence
# i= 50 :Processed and saved V_59.mp4 to /kaggle/working/ds/Violence
# i= 51 :Processed and saved V_530.mp4 to /kaggle/working/ds/Violence
# i= 52 :Processed and saved V_935.mp4 to /kaggle/working/ds/Violence
# i= 53 :Processed and saved V_124.mp4 to /kaggle/working/ds/Violence
# i= 54 :Processed and saved V_370.mp4 to /kaggle/working/ds/Violence
# i= 55 :Processed and saved V_865.mp4 to /kaggle/working/ds/Violence
# i= 56 :Processed and saved V_175.mp4 to /kaggle/working/ds/Violence
# i= 57 :Processed and saved V_72.mp4 to /kaggle/working/ds/Violence
# i= 58 :Processed and saved V_245.mp4 to /kaggle/working/ds/Violence
# i= 59 :Processed and saved V_240.mp4 to /kaggle/working/ds/Violence
# i= 60 :Processed and saved V_473.mp4 to /kaggle/working/ds/Violence
# i= 61 :Processed and saved V_946.mp4 to /kaggle/working/ds/Violence
# i= 62 :Processed and saved V_891.mp4 to /kaggle/working/ds/Violence
# i= 63 :Processed and saved V_524.mp4 to /kaggle/working/ds/Violence
# i= 64 :Processed and saved V_196.mp4 to /kaggle/working/ds/Violence
# i= 65 :Processed and saved V_274.mp4 to /kaggle/working/ds/Violence
# i= 66 :Processed and saved V_349.mp4 to /kaggle/working/ds/Violence
# i= 67 :Processed and saved V_928.mp4 to /kaggle/working/ds/Violence
# i= 68 :Processed and saved V_479.mp4 to /kaggle/working/ds/Violence
# i= 69 :Processed and saved V_277.mp4 to /kaggle/working/ds/Violence
# i= 70 :Processed and saved V_313.mp4 to /kaggle/working/ds/Violence
# i= 71 :Processed and saved V_585.mp4 to /kaggle/working/ds/Violence
# i= 72 :Processed and saved V_211.mp4 to /kaggle/working/ds/Violence
# i= 73 :Processed and saved V_984.mp4 to /kaggle/working/ds/Violence
# i= 74 :Processed and saved V_623.mp4 to /kaggle/working/ds/Violence
# i= 75 :Processed and saved V_722.mp4 to /kaggle/working/ds/Violence
# i= 76 :Processed and saved V_157.mp4 to /kaggle/working/ds/Violence
# i= 77 :Processed and saved V_893.mp4 to /kaggle/working/ds/Violence
# i= 78 :Processed and saved V_98.mp4 to /kaggle/working/ds/Violence
# i= 79 :Processed and saved V_517.mp4 to /kaggle/working/ds/Violence
# i= 80 :Processed and saved V_474.mp4 to /kaggle/working/ds/Violence
# i= 81 :Processed and saved V_174.mp4 to /kaggle/working/ds/Violence
# i= 82 :Processed and saved V_931.mp4 to /kaggle/working/ds/Violence
# i= 83 :Processed and saved V_973.mp4 to /kaggle/working/ds/Violence
# i= 84 :Processed and saved V_603.mp4 to /kaggle/working/ds/Violence
# i= 85 :Processed and saved V_677.mp4 to /kaggle/working/ds/Violence
# i= 86 :Processed and saved V_750.mp4 to /kaggle/working/ds/Violence
# i= 87 :Processed and saved V_826.mp4 to /kaggle/working/ds/Violence
# i= 88 :Processed and saved V_2.mp4 to /kaggle/working/ds/Violence
# i= 89 :Processed and saved V_736.mp4 to /kaggle/working/ds/Violence
# i= 90 :Processed and saved V_208.mp4 to /kaggle/working/ds/Violence
# i= 91 :Processed and saved V_311.mp4 to /kaggle/working/ds/Violence
# i= 92 :Processed and saved V_233.mp4 to /kaggle/working/ds/Violence
# i= 93 :Processed and saved V_82.mp4 to /kaggle/working/ds/Violence
# i= 94 :Processed and saved V_25.mp4 to /kaggle/working/ds/Violence
# i= 95 :Processed and saved V_193.mp4 to /kaggle/working/ds/Violence
# i= 96 :Processed and saved V_918.mp4 to /kaggle/working/ds/Violence
# i= 97 :Processed and saved V_477.mp4 to /kaggle/working/ds/Violence
# i= 98 :Processed and saved V_718.mp4 to /kaggle/working/ds/Violence
# i= 99 :Processed and saved V_401.mp4 to /kaggle/working/ds/Violence
# i= 100 :Processed and saved V_827.mp4 to /kaggle/working/ds/Violence
# i= 101 :Processed and saved V_448.mp4 to /kaggle/working/ds/Violence
# i= 102 :Processed and saved V_997.mp4 to /kaggle/working/ds/Violence
# i= 103 :Processed and saved V_952.mp4 to /kaggle/working/ds/Violence
# i= 104 :Processed and saved V_955.mp4 to /kaggle/working/ds/Violence
# i= 105 :Processed and saved V_600.mp4 to /kaggle/working/ds/Violence
# i= 106 :Processed and saved V_669.mp4 to /kaggle/working/ds/Violence
# i= 107 :Processed and saved V_548.mp4 to /kaggle/working/ds/Violence
# i= 108 :Processed and saved V_470.mp4 to /kaggle/working/ds/Violence
# i= 109 :Processed and saved V_892.mp4 to /kaggle/working/ds/Violence
# i= 110 :Processed and saved V_544.mp4 to /kaggle/working/ds/Violence
# i= 111 :Processed and saved V_251.mp4 to /kaggle/working/ds/Violence
# i= 112 :Processed and saved V_9.mp4 to /kaggle/working/ds/Violence
# i= 113 :Processed and saved V_118.mp4 to /kaggle/working/ds/Violence
# i= 114 :Processed and saved V_97.mp4 to /kaggle/working/ds/Violence
# i= 115 :Processed and saved V_950.mp4 to /kaggle/working/ds/Violence
# i= 116 :Processed and saved V_37.mp4 to /kaggle/working/ds/Violence
# i= 117 :Processed and saved V_549.mp4 to /kaggle/working/ds/Violence
# i= 118 :Processed and saved V_42.mp4 to /kaggle/working/ds/Violence
# i= 119 :Processed and saved V_536.mp4 to /kaggle/working/ds/Violence
# i= 120 :Processed and saved V_379.mp4 to /kaggle/working/ds/Violence
# i= 121 :Processed and saved V_279.mp4 to /kaggle/working/ds/Violence
# i= 122 :Processed and saved V_999.mp4 to /kaggle/working/ds/Violence
# i= 123 :Processed and saved V_435.mp4 to /kaggle/working/ds/Violence
# i= 124 :Processed and saved V_81.mp4 to /kaggle/working/ds/Violence
# i= 125 :Processed and saved V_883.mp4 to /kaggle/working/ds/Violence
# i= 126 :Processed and saved V_475.mp4 to /kaggle/working/ds/Violence
# i= 127 :Processed and saved V_402.mp4 to /kaggle/working/ds/Violence
# i= 128 :Processed and saved V_300.mp4 to /kaggle/working/ds/Violence
# i= 129 :Processed and saved V_182.mp4 to /kaggle/working/ds/Violence
# i= 130 :Processed and saved V_982.mp4 to /kaggle/working/ds/Violence
# i= 131 :Processed and saved V_919.mp4 to /kaggle/working/ds/Violence
# i= 132 :Processed and saved V_945.mp4 to /kaggle/working/ds/Violence
# i= 133 :Processed and saved V_225.mp4 to /kaggle/working/ds/Violence
# i= 134 :Processed and saved V_315.mp4 to /kaggle/working/ds/Violence
# i= 135 :Processed and saved V_953.mp4 to /kaggle/working/ds/Violence
# i= 136 :Processed and saved V_422.mp4 to /kaggle/working/ds/Violence
# i= 137 :Processed and saved V_824.mp4 to /kaggle/working/ds/Violence
# i= 138 :Processed and saved V_106.mp4 to /kaggle/working/ds/Violence
# i= 139 :Processed and saved V_8.mp4 to /kaggle/working/ds/Violence
# i= 140 :Processed and saved V_616.mp4 to /kaggle/working/ds/Violence
# i= 141 :Processed and saved V_836.mp4 to /kaggle/working/ds/Violence
# i= 142 :Processed and saved V_297.mp4 to /kaggle/working/ds/Violence
# i= 143 :Processed and saved V_857.mp4 to /kaggle/working/ds/Violence
# i= 144 :Processed and saved V_361.mp4 to /kaggle/working/ds/Violence
# i= 145 :Processed and saved V_7.mp4 to /kaggle/working/ds/Violence
# i= 146 :Processed and saved V_866.mp4 to /kaggle/working/ds/Violence
# i= 147 :Processed and saved V_706.mp4 to /kaggle/working/ds/Violence
# i= 148 :Processed and saved V_966.mp4 to /kaggle/working/ds/Violence
# i= 149 :Processed and saved V_772.mp4 to /kaggle/working/ds/Violence
# i= 150 :Processed and saved V_60.mp4 to /kaggle/working/ds/Violence
# i= 151 :Processed and saved NV_624.mp4 to /kaggle/working/ds/NonViolence
# i= 152 :Processed and saved NV_24.mp4 to /kaggle/working/ds/NonViolence
# i= 153 :Processed and saved NV_618.mp4 to /kaggle/working/ds/NonViolence
# i= 154 :Processed and saved NV_924.mp4 to /kaggle/working/ds/NonViolence
# i= 155 :Processed and saved NV_25.mp4 to /kaggle/working/ds/NonViolence
# i= 156 :Processed and saved NV_470.mp4 to /kaggle/working/ds/NonViolence
# i= 157 :Processed and saved NV_817.mp4 to /kaggle/working/ds/NonViolence
# i= 158 :Processed and saved NV_58.mp4 to /kaggle/working/ds/NonViolence
# i= 159 :Processed and saved NV_188.mp4 to /kaggle/working/ds/NonViolence
# i= 160 :Processed and saved NV_131.mp4 to /kaggle/working/ds/NonViolence
# i= 161 :Processed and saved NV_905.avi to /kaggle/working/ds/NonViolence
# i= 162 :Processed and saved NV_738.mp4 to /kaggle/working/ds/NonViolence
# i= 163 :Processed and saved NV_570.mp4 to /kaggle/working/ds/NonViolence
# i= 164 :Processed and saved NV_952.mp4 to /kaggle/working/ds/NonViolence
# i= 165 :Processed and saved NV_786.mp4 to /kaggle/working/ds/NonViolence
# i= 166 :Processed and saved NV_651.mp4 to /kaggle/working/ds/NonViolence
# i= 167 :Processed and saved NV_996.mp4 to /kaggle/working/ds/NonViolence
# i= 168 :Processed and saved NV_197.mp4 to /kaggle/working/ds/NonViolence
# i= 169 :Processed and saved NV_254.mp4 to /kaggle/working/ds/NonViolence
# i= 170 :Processed and saved NV_538.mp4 to /kaggle/working/ds/NonViolence
# i= 171 :Processed and saved NV_513.mp4 to /kaggle/working/ds/NonViolence
# i= 172 :Processed and saved NV_272.mp4 to /kaggle/working/ds/NonViolence
# i= 173 :Processed and saved NV_703.mp4 to /kaggle/working/ds/NonViolence
# i= 174 :Processed and saved NV_100.mp4 to /kaggle/working/ds/NonViolence
# i= 175 :Processed and saved NV_303.mp4 to /kaggle/working/ds/NonViolence
# i= 176 :Processed and saved NV_885.avi to /kaggle/working/ds/NonViolence
# i= 177 :Processed and saved NV_814.mp4 to /kaggle/working/ds/NonViolence
# i= 178 :Processed and saved NV_664.mp4 to /kaggle/working/ds/NonViolence
# i= 179 :Processed and saved NV_176.mp4 to /kaggle/working/ds/NonViolence
# i= 180 :Processed and saved NV_807.mp4 to /kaggle/working/ds/NonViolence
# i= 181 :Processed and saved NV_427.mp4 to /kaggle/working/ds/NonViolence
# i= 182 :Processed and saved NV_582.mp4 to /kaggle/working/ds/NonViolence
# i= 183 :Processed and saved NV_503.mp4 to /kaggle/working/ds/NonViolence
# i= 184 :Processed and saved NV_302.mp4 to /kaggle/working/ds/NonViolence
# i= 185 :Processed and saved NV_182.mp4 to /kaggle/working/ds/NonViolence
# i= 186 :Processed and saved NV_978.mp4 to /kaggle/working/ds/NonViolence
# i= 187 :Processed and saved NV_355.mp4 to /kaggle/working/ds/NonViolence
# i= 188 :Processed and saved NV_258.mp4 to /kaggle/working/ds/NonViolence
# i= 189 :Processed and saved NV_901.avi to /kaggle/working/ds/NonViolence
# i= 190 :Processed and saved NV_893.avi to /kaggle/working/ds/NonViolence
# i= 191 :Processed and saved NV_797.mp4 to /kaggle/working/ds/NonViolence
# i= 192 :Processed and saved NV_312.mp4 to /kaggle/working/ds/NonViolence
# i= 193 :Processed and saved NV_151.mp4 to /kaggle/working/ds/NonViolence
# i= 194 :Processed and saved NV_4.mp4 to /kaggle/working/ds/NonViolence
# i= 195 :Processed and saved NV_623.mp4 to /kaggle/working/ds/NonViolence
# i= 196 :Processed and saved NV_897.avi to /kaggle/working/ds/NonViolence
# i= 197 :Processed and saved NV_105.mp4 to /kaggle/working/ds/NonViolence
# i= 198 :Processed and saved NV_862.mp4 to /kaggle/working/ds/NonViolence
# i= 199 :Processed and saved NV_554.mp4 to /kaggle/working/ds/NonViolence
# i= 200 :Processed and saved NV_831.mp4 to /kaggle/working/ds/NonViolence
# i= 201 :Processed and saved NV_435.mp4 to /kaggle/working/ds/NonViolence
# i= 202 :Processed and saved NV_915.mp4 to /kaggle/working/ds/NonViolence
# i= 203 :Processed and saved NV_631.mp4 to /kaggle/working/ds/NonViolence
# i= 204 :Processed and saved NV_790.mp4 to /kaggle/working/ds/NonViolence
# i= 205 :Processed and saved NV_638.mp4 to /kaggle/working/ds/NonViolence
# i= 206 :Processed and saved NV_802.mp4 to /kaggle/working/ds/NonViolence
# i= 207 :Processed and saved NV_422.mp4 to /kaggle/working/ds/NonViolence
# i= 208 :Processed and saved NV_721.mp4 to /kaggle/working/ds/NonViolence
# i= 209 :Processed and saved NV_880.avi to /kaggle/working/ds/NonViolence
# i= 210 :Processed and saved NV_374.mp4 to /kaggle/working/ds/NonViolence
# i= 211 :Processed and saved NV_316.mp4 to /kaggle/working/ds/NonViolence
# i= 212 :Processed and saved NV_663.mp4 to /kaggle/working/ds/NonViolence
# i= 213 :Processed and saved NV_368.mp4 to /kaggle/working/ds/NonViolence
# i= 214 :Processed and saved NV_548.mp4 to /kaggle/working/ds/NonViolence
# i= 215 :Processed and saved NV_157.mp4 to /kaggle/working/ds/NonViolence
# i= 216 :Processed and saved NV_918.mp4 to /kaggle/working/ds/NonViolence
# i= 217 :Processed and saved NV_810.mp4 to /kaggle/working/ds/NonViolence
# i= 218 :Processed and saved NV_744.mp4 to /kaggle/working/ds/NonViolence
# i= 219 :Processed and saved NV_798.mp4 to /kaggle/working/ds/NonViolence
# i= 220 :Processed and saved NV_564.mp4 to /kaggle/working/ds/NonViolence
# i= 221 :Processed and saved NV_190.mp4 to /kaggle/working/ds/NonViolence
# i= 222 :Processed and saved NV_317.mp4 to /kaggle/working/ds/NonViolence
# i= 223 :Processed and saved NV_326.mp4 to /kaggle/working/ds/NonViolence
# i= 224 :Processed and saved NV_964.mp4 to /kaggle/working/ds/NonViolence
# i= 225 :Processed and saved NV_88.mp4 to /kaggle/working/ds/NonViolence
# i= 226 :Processed and saved NV_588.mp4 to /kaggle/working/ds/NonViolence
# i= 227 :Processed and saved NV_351.mp4 to /kaggle/working/ds/NonViolence
# i= 228 :Processed and saved NV_85.mp4 to /kaggle/working/ds/NonViolence
# i= 229 :Processed and saved NV_300.mp4 to /kaggle/working/ds/NonViolence
# i= 230 :Processed and saved NV_116.mp4 to /kaggle/working/ds/NonViolence
# i= 231 :Processed and saved NV_599.mp4 to /kaggle/working/ds/NonViolence
# i= 232 :Processed and saved NV_506.mp4 to /kaggle/working/ds/NonViolence
# i= 233 :Processed and saved NV_174.mp4 to /kaggle/working/ds/NonViolence
# i= 234 :Processed and saved NV_226.mp4 to /kaggle/working/ds/NonViolence
# i= 235 :Processed and saved NV_961.mp4 to /kaggle/working/ds/NonViolence
# i= 236 :Processed and saved NV_64.mp4 to /kaggle/working/ds/NonViolence
# i= 237 :Processed and saved NV_921.mp4 to /kaggle/working/ds/NonViolence
# i= 238 :Processed and saved NV_713.mp4 to /kaggle/working/ds/NonViolence
# i= 239 :Processed and saved NV_71.mp4 to /kaggle/working/ds/NonViolence
# i= 240 :Processed and saved NV_971.mp4 to /kaggle/working/ds/NonViolence
# i= 241 :Processed and saved NV_825.mp4 to /kaggle/working/ds/NonViolence
# i= 242 :Processed and saved NV_447.mp4 to /kaggle/working/ds/NonViolence
# i= 243 :Processed and saved NV_382.mp4 to /kaggle/working/ds/NonViolence
# i= 244 :Processed and saved NV_689.mp4 to /kaggle/working/ds/NonViolence
# i= 245 :Processed and saved NV_44.mp4 to /kaggle/working/ds/NonViolence
# i= 246 :Processed and saved NV_369.mp4 to /kaggle/working/ds/NonViolence
# i= 247 :Processed and saved NV_158.mp4 to /kaggle/working/ds/NonViolence
# i= 248 :Processed and saved NV_304.mp4 to /kaggle/working/ds/NonViolence
# i= 249 :Processed and saved NV_241.mp4 to /kaggle/working/ds/NonViolence
# i= 250 :Processed and saved NV_515.mp4 to /kaggle/working/ds/NonViolence
# i= 251 :Processed and saved NV_820.mp4 to /kaggle/working/ds/NonViolence
# i= 252 :Processed and saved NV_998.mp4 to /kaggle/working/ds/NonViolence
# i= 253 :Processed and saved NV_225.mp4 to /kaggle/working/ds/NonViolence
# i= 254 :Processed and saved NV_409.mp4 to /kaggle/working/ds/NonViolence
# i= 255 :Processed and saved NV_784.mp4 to /kaggle/working/ds/NonViolence
# i= 256 :Processed and saved NV_337.mp4 to /kaggle/working/ds/NonViolence
# i= 257 :Processed and saved NV_904.avi to /kaggle/working/ds/NonViolence
# i= 258 :Processed and saved NV_597.mp4 to /kaggle/working/ds/NonViolence
# i= 259 :Processed and saved NV_584.mp4 to /kaggle/working/ds/NonViolence
# i= 260 :Processed and saved NV_487.mp4 to /kaggle/working/ds/NonViolence
# i= 261 :Processed and saved NV_424.mp4 to /kaggle/working/ds/NonViolence
# i= 262 :Processed and saved NV_353.mp4 to /kaggle/working/ds/NonViolence
# i= 263 :Processed and saved NV_620.mp4 to /kaggle/working/ds/NonViolence
# i= 264 :Processed and saved NV_544.mp4 to /kaggle/working/ds/NonViolence
# i= 265 :Processed and saved NV_306.mp4 to /kaggle/working/ds/NonViolence
# i= 266 :Processed and saved NV_98.mp4 to /kaggle/working/ds/NonViolence
# i= 267 :Processed and saved NV_793.mp4 to /kaggle/working/ds/NonViolence
# i= 268 :Processed and saved NV_454.mp4 to /kaggle/working/ds/NonViolence
# i= 269 :Processed and saved NV_129.mp4 to /kaggle/working/ds/NonViolence
# i= 270 :Processed and saved NV_55.mp4 to /kaggle/working/ds/NonViolence
# i= 271 :Processed and saved NV_40.mp4 to /kaggle/working/ds/NonViolence
# i= 272 :Processed and saved NV_112.mp4 to /kaggle/working/ds/NonViolence
# i= 273 :Processed and saved NV_403.mp4 to /kaggle/working/ds/NonViolence
# i= 274 :Processed and saved NV_464.mp4 to /kaggle/working/ds/NonViolence
# i= 275 :Processed and saved NV_247.mp4 to /kaggle/working/ds/NonViolence
# i= 276 :Processed and saved NV_745.mp4 to /kaggle/working/ds/NonViolence
# i= 277 :Processed and saved NV_903.avi to /kaggle/working/ds/NonViolence
# i= 278 :Processed and saved NV_693.mp4 to /kaggle/working/ds/NonViolence
# i= 279 :Processed and saved NV_244.mp4 to /kaggle/working/ds/NonViolence
# i= 280 :Processed and saved NV_822.mp4 to /kaggle/working/ds/NonViolence
# i= 281 :Processed and saved NV_240.mp4 to /kaggle/working/ds/NonViolence
# i= 282 :Processed and saved NV_327.mp4 to /kaggle/working/ds/NonViolence
# i= 283 :Processed and saved NV_20.mp4 to /kaggle/working/ds/NonViolence
# i= 284 :Processed and saved NV_6.mp4 to /kaggle/working/ds/NonViolence
# i= 285 :Processed and saved NV_636.mp4 to /kaggle/working/ds/NonViolence
# i= 286 :Processed and saved NV_75.mp4 to /kaggle/working/ds/NonViolence
# i= 287 :Processed and saved NV_630.mp4 to /kaggle/working/ds/NonViolence
# i= 288 :Processed and saved NV_886.avi to /kaggle/working/ds/NonViolence
# i= 289 :Processed and saved NV_220.mp4 to /kaggle/working/ds/NonViolence
# i= 290 :Processed and saved NV_951.mp4 to /kaggle/working/ds/NonViolence
# i= 291 :Processed and saved NV_290.mp4 to /kaggle/working/ds/NonViolence
# i= 292 :Processed and saved NV_367.mp4 to /kaggle/working/ds/NonViolence
# i= 293 :Processed and saved NV_647.mp4 to /kaggle/working/ds/NonViolence
# i= 294 :Processed and saved NV_994.mp4 to /kaggle/working/ds/NonViolence
# i= 295 :Processed and saved NV_420.mp4 to /kaggle/working/ds/NonViolence
# i= 296 :Processed and saved NV_46.mp4 to /kaggle/working/ds/NonViolence
# i= 297 :Processed and saved NV_81.mp4 to /kaggle/working/ds/NonViolence
# i= 298 :Processed and saved NV_344.mp4 to /kaggle/working/ds/NonViolence
# i= 299 :Processed and saved NV_958.mp4 to /kaggle/working/ds/NonViolence
# i= 300 :Processed and saved NV_32.mp4 to /kaggle/working/ds/NonViolence

# %%
#-- Zip Data -----------------------------------------------------------------------------------------------------
ds_zip_file = '/kaggle/working/data'
shutil.make_archive(ds_zip_file, 'zip', ds_preprocessed_path)
shutil.rmtree(ds_preprocessed_path)
#-------------------------------------------------------------------------------------------------------------
